# %% [markdown]
# <p align="center">
#   <img src="../Images/datasafari-logo-primary.png" width="300">
# </p>
#
# ---

# %% [markdown]
# # 📊 Capstone Project: Exploratory Data Analysis
#
# >⏱️ Duration: 60–75 minutes
# >📊 Dataset: `Adult_cleaned.csv` (Census Income Dataset)
#
#
# 📌 **Project Context**
#
# You are a data analyst working for a policy and labor economics research team.
# Your task is to explore a census dataset (`Adult_cleaned.csv`) to understand demographic patterns, education, employment, and income-related trends.
#
# Before building any predictive model, you must understand the data using Exploratory Data Analysis (EDA).
#
# 🎯 **Project Objectives**
#
# By the end of this project, you should be able to:
#
# - Summarize numerical and categorical data
#
# - Visualize distributions and detect outliers
#
# - Compare categories visually
#
# - Explore relationships between variables
#
# - Interpret correlations
#
# - Communicate insights clearly using Markdown
#
# ---

# %% [markdown]
# ### **Import required libraries**

# %%
import seaborn as sns # data visualization library
import matplotlib.pyplot as plt # plotting library
import pandas as pd # data manipulation library
import numpy as np # numerical operations library

# %% [markdown]
# ## 1️⃣ Load and Inspect the Dataset
#
# **Task:** Load the dataset and inspect its structure.
#
# - Load `Adult.csv` into a Pandas DataFrame
# - Display the first 5 rows
# - Check shape and data types
#
# ✍️ *Write brief observations in Markdown after running the code.*

# %%
# TODO: Import libraries and load the dataset
import pandas as pd

# df = pd.read_csv('Adult.csv')
# df.head()

# %% [markdown]
# - How many rows and columns does the dataset have?
# - Which columns are numerical? Which are categorical?
# - Are there any columns that may need cleaning or recoding?

# %% [markdown]
# ## 2️⃣ Summary Statistics (Numerical Features)
#
# **Task:** Compute and interpret summary statistics.
#
# - Mean, median, mode, standard deviation
# - Identify which variables are skewed
#
# ✍️ *Add interpretation below.*

# %%
# TODO: Compute summary statistics for numerical columns
# df.describe()

# %% [markdown]
# - Which numerical variable has the highest variability? Why?
# - Is the mean close to the median for age? What does this suggest?
# - Which variable appears most skewed?

# %% [markdown]
# ## 3️⃣ Distribution Analysis 📈
#
# **Task:** Visualize distributions of numerical variables.
#
# - Plot **Histogram + KDE** for `age`
# - Plot **Boxplot** for `age`
#
# ✍️ *Comment on skewness and outliers.*

# %%
# TODO: Plot histogram, and KDE 

# sns.histplot(df['age'], kde=True)
# plt.show()

# %%
# boxplot for age
# sns.boxplot(x=df['age'])
# plt.show()

# %% [markdown]
# - Are the distributions symmetric or skewed?
# - Which variable has more extreme outliers?
# - How does KDE help compared to histogram alone?
# - What real-world explanations might explain the outliers?

# %% [markdown]
# ## 4️⃣ Categorical Data Analysis 🧩
#
# **Task:** Analyze categorical variables.
#
# - Create countplots for `sex`, `education`, `marital-status`
# - Use `hue` to compare one variable by another
#
# ✍️ *Which categories dominate?*

# %%
# TODO: Create countplots for categorical variables
# sns.countplot(x='sex', data=df)
# plt.show()

# %% [markdown]
# - Which education level is most common?
# - Is income evenly distributed across genders?
# - Which marital status dominates the dataset?
# - Why are count plots preferred over pie charts in most analyses?

# %% [markdown]
# ## 5️⃣ Relationship Analysis (Scatterplots and Correlation) 🔗
#
# **Task:** Explore relationships between numerical variables.
#
# - Scatterplot: `age` vs `hours-per-week`
# - Add a regression line
# - Compute correlation coefficient
#
# ✍️ *Is the relationship strong, weak, or none?*

# %%
# TODO: Scatterplot with regression line and correlation
# sns.regplot(x='age', y='hours-per-week', data=df)
# plt.show()

# df[['age', 'hours-per-week']].corr()

# %% [markdown]
# - Do people earning >50K tend to work more hours?
# - Is age strongly associated with income category?
# - What does overlap in boxplots suggest?

# %% [markdown]
# ## 6️⃣ Correlation Heatmap 🔥
#
# **Task:** Visualize correlations among numerical features.
#
# - Create a correlation matrix
# - Plot a heatmap
# - Identify strong correlations (|r| > 0.5)
#
# ✍️ *What do these correlations suggest?*

# %%
# TODO: Correlation heatmap
# corr = df.corr(numeric_only=True)
# sns.heatmap(corr, annot=True, cmap='coolwarm')
# plt.show()

# %% [markdown]
# - Is the relationship strong, weak, or negligible?
# - Does the regression line suggest a positive or negative trend?
# - Why might correlation be low even if points appear scattered?

# %% [markdown]
# ## 7️⃣ Final Observations & Reflection 📝
#
# **Task:** Summarize your findings.
#
# - Key patterns in age and work hours
# - Dominant categories
# - Interesting or surprising relationships
#
# ✍️ *Use bullet points for clarity.*

# %% [markdown]
# ---
# <p align="center">
#   <img src="../Images/datasafari-logo-primary.png" width="300">
# </p>
